# %%
import pandas as pd
pd.set_option('display.max_columns',None)

# %%
tree_census = pd.read_csv("2015_Street_Tree_Census_-_Tree_Data.csv")
tree_census
# Out:
#         tree_id  block_id  created_at  tree_dbh  stump_diam curb_loc status  \
# 0        180683    348711  08/27/2015         3           0   OnCurb  Alive
# 1        200540    315986  09/03/2015        21           0   OnCurb  Alive
# 2        204026    218365  09/05/2015         3           0   OnCurb  Alive
# 3        204337    217969  09/05/2015        10           0   OnCurb  Alive
# 4        189565    223043  08/30/2015        21           0   OnCurb  Alive
# ...         ...       ...         ...       ...         ...      ...    ...
# 165887   375556    326928  10/25/2015        32           0   OnCurb  Alive
# 165888   378555    210105  10/26/2015        26           0   OnCurb  Alive
# 165889   378557    210105  10/26/2015        23           0   OnCurb  Alive
# 165890   378623    210242  10/26/2015        32           0   OnCurb  Alive
# 165891   352562    505836  10/20/2015         3           0   OnCurb  Alive
#
#        health                           spc_latin           spc_common  \
# 0        Fair                         Acer rubrum            red maple
# 1        Fair                   Quercus palustris              pin oak
# 2        Good  Gleditsia triacanthos var. inermis          honeylocust
# 3        Good  Gleditsia triacanthos var. inermis          honeylocust
# 4        Good                     Tilia americana      American linden
# ...       ...                                 ...                  ...
# 165887   Good               Platanus x acerifolia     London planetree
# 165888   Good               Platanus x acerifolia     London planetree
# 165889   Good               Platanus x acerifolia     London planetree
# 165890   Good               Platanus x acerifolia     London planetree
# 165891   Fair                 Gymnocladus dioicus  Kentucky coffeetree
#
#        steward guards  sidewalk         user_type             problems  \
# 0         None   None  NoDamage  TreesCount Staff                 None
# 1         None   None    Damage  TreesCount Staff               Stones
# 2         1or2   None    Damage         Volunteer                 None
# 3         None   None    Damage         Volunteer               Stones
# 4         None   None    Damage         Volunteer               Stones
# ...        ...    ...       ...               ...                  ...
# 165887    1or2   None  NoDamage         Volunteer         BranchLights
# 165888    None   None  NoDamage   NYC Parks Staff                 None
# 165889    None   None  NoDamage   NYC Parks Staff                 None
# 165890    None   None    Damage   NYC Parks Staff  Stones,BranchLights
# 165891    None   None  NoDamage   NYC Parks Staff          BranchOther
#
#        root_stone root_grate root_other trunk_wire trnk_light trnk_other  \
# 0              No         No         No         No         No         No
# 1             Yes         No         No         No         No         No
# 2              No         No         No         No         No         No
# 3             Yes         No         No         No         No         No
# 4             Yes         No         No         No         No         No
# ...           ...        ...        ...        ...        ...        ...
# 165887         No         No         No         No         No         No
# 165888         No         No         No         No         No         No
# 165889         No         No         No         No         No         No
# 165890        Yes         No         No         No         No         No
# 165891         No         No         No         No         No        NaN
#
#        brch_light brch_shoe brch_other              address  postcode  \
# 0              No        No         No    108-005 70 AVENUE   11375.0
# 1              No        No         No     147-074 7 AVENUE   11357.0
# 2              No        No         No    390 MORGAN AVENUE   11211.0
# 3              No        No         No    1027 GRAND STREET   11211.0
# 4              No        No         No         603 6 STREET   11215.0
# ...           ...       ...        ...                  ...       ...
# 165887        Yes        No         No   111-024 169 STREET   11433.0
# 165888         No        No         No  1970 EAST 23 STREET   11229.0
# 165889         No        No         No  1974 EAST 23 STREET   11229.0
# 165890        Yes        No         No  1868 EAST 24 STREET   11229.0
# 165891        NaN       NaN        NaN                  NaN       NaN
#
#             zip_city  community board  borocode   borough  cncldist  st_assem  \
# 0       Forest Hills            406.0       4.0    Queens      29.0      28.0
# 1         Whitestone            407.0       4.0    Queens      19.0      27.0
# 2           Brooklyn            301.0       3.0  Brooklyn      34.0      50.0
# 3           Brooklyn            301.0       3.0  Brooklyn      34.0      53.0
# 4           Brooklyn            306.0       3.0  Brooklyn      39.0      44.0
# ...              ...              ...       ...       ...       ...       ...
# 165887       Jamaica            412.0       4.0    Queens      27.0      32.0
# 165888      Brooklyn            315.0       3.0  Brooklyn      48.0      41.0
# 165889      Brooklyn            315.0       3.0  Brooklyn      48.0      41.0
# 165890      Brooklyn            315.0       3.0  Brooklyn      48.0      41.0
# 165891           NaN              NaN       NaN       NaN       NaN       NaN
#
#         st_senate   nta            nta_name    boro_ct     state   latitude  \
# 0            16.0  QN17        Forest Hills  4073900.0  New York  40.723092
# 1            11.0  QN49          Whitestone  4097300.0  New York  40.794111
# 2            18.0  BK90   East Williamsburg  3044900.0  New York  40.717581
# 3            18.0  BK90   East Williamsburg  3044900.0  New York  40.713537
# 4            21.0  BK37  Park Slope-Gowanus  3016500.0  New York  40.666778
# ...           ...   ...                 ...        ...       ...        ...
# 165887       14.0  QN01       South Jamaica  4026600.0  New York  40.693249
# 165888       17.0  BK44             Madison  3056000.0  New York  40.602678
# 165889       17.0  BK44             Madison  3056000.0  New York  40.602551
# 165890       17.0  BK44             Madison  3056200.0  New York  40.605136
# 165891        NaN   NaN                 NaN        NaN       NaN        NaN
#
#         longitude          x_sp         y_sp  council district  census tract  \
# 0      -73.844215  1.027431e+06  202756.7687              29.0         739.0
# 1      -73.818679  1.034456e+06  228644.8374              19.0         973.0
# 2      -73.936608  1.001823e+06  200716.8913              34.0         449.0
# 3      -73.934456  1.002420e+06  199244.2531              34.0         449.0
# 4      -73.975979  9.909138e+05  182202.4260              39.0         165.0
# ...           ...           ...          ...               ...           ...
# 165887 -73.782444  1.044580e+06  191920.6710              27.0         266.0
# 165888 -73.949150  9.983704e+05  158852.2854              48.0         560.0
# 165889 -73.949126  9.983771e+05  158805.9734              48.0         560.0
# 165890 -73.948663  9.985049e+05  159748.1031              48.0         562.0
# 165891        NaN           NaN          NaN               NaN           NaN
#
#               bin           bbl
# 0       4052307.0  4.022210e+09
# 1       4101931.0  4.044750e+09
# 2       3338310.0  3.028870e+09
# 3       3338342.0  3.029250e+09
# 4       3025654.0  3.010850e+09
# ...           ...           ...
# 165887  4217314.0  4.102060e+09
# 165888  3197172.0  3.073010e+09
# 165889  3197174.0  3.073010e+09
# 165890  3184290.0  3.068290e+09
# 165891        NaN           NaN
#
# [165892 rows x 45 columns]

# %%
tree_census.columns
# Out:
# Index(['tree_id', 'block_id', 'created_at', 'tree_dbh', 'stump_diam',
#        'curb_loc', 'status', 'health', 'spc_latin', 'spc_common', 'steward',
#        'guards', 'sidewalk', 'user_type', 'problems', 'root_stone',
#        'root_grate', 'root_other', 'trunk_wire', 'trnk_light', 'trnk_other',
#        'brch_light', 'brch_shoe', 'brch_other', 'address', 'postcode',
#        'zip_city', 'community board', 'borocode', 'borough', 'cncldist',
#        'st_assem', 'st_senate', 'nta', 'nta_name', 'boro_ct', 'state',
#        'latitude', 'longitude', 'x_sp', 'y_sp', 'council district',
#        'census tract', 'bin', 'bbl'],
#       dtype='object')

# %%
tree_census_subset = tree_census[['tree_id', 'tree_dbh', 'stump_diam',
       'curb_loc', 'status', 'health', 'spc_latin', 'steward', 'sidewalk', 'problems', 'root_stone',
       'root_grate', 'root_other', 'trunk_wire', 'trnk_light', 'trnk_other',
       'brch_light', 'brch_shoe', 'brch_other']]
tree_census_subset
# Out:
#         tree_id  tree_dbh  stump_diam curb_loc status health  \
# 0        180683         3           0   OnCurb  Alive   Fair
# 1        200540        21           0   OnCurb  Alive   Fair
# 2        204026         3           0   OnCurb  Alive   Good
# 3        204337        10           0   OnCurb  Alive   Good
# 4        189565        21           0   OnCurb  Alive   Good
# ...         ...       ...         ...      ...    ...    ...
# 165887   375556        32           0   OnCurb  Alive   Good
# 165888   378555        26           0   OnCurb  Alive   Good
# 165889   378557        23           0   OnCurb  Alive   Good
# 165890   378623        32           0   OnCurb  Alive   Good
# 165891   352562         3           0   OnCurb  Alive   Fair
#
#                                  spc_latin steward  sidewalk  \
# 0                              Acer rubrum    None  NoDamage
# 1                        Quercus palustris    None    Damage
# 2       Gleditsia triacanthos var. inermis    1or2    Damage
# 3       Gleditsia triacanthos var. inermis    None    Damage
# 4                          Tilia americana    None    Damage
# ...                                    ...     ...       ...
# 165887               Platanus x acerifolia    1or2  NoDamage
# 165888               Platanus x acerifolia    None  NoDamage
# 165889               Platanus x acerifolia    None  NoDamage
# 165890               Platanus x acerifolia    None    Damage
# 165891                 Gymnocladus dioicus    None  NoDamage
#
#                    problems root_stone root_grate root_other trunk_wire  \
# 0                      None         No         No         No         No
# 1                    Stones        Yes         No         No         No
# 2                      None         No         No         No         No
# 3                    Stones        Yes         No         No         No
# 4                    Stones        Yes         No         No         No
# ...                     ...        ...        ...        ...        ...
# 165887         BranchLights         No         No         No         No
# 165888                 None         No         No         No         No
# 165889                 None         No         No         No         No
# 165890  Stones,BranchLights        Yes         No         No         No
# 165891          BranchOther         No         No         No         No
#
#        trnk_light trnk_other brch_light brch_shoe brch_other
# 0              No         No         No        No         No
# 1              No         No         No        No         No
# 2              No         No         No        No         No
# 3              No         No         No        No         No
# 4              No         No         No        No         No
# ...           ...        ...        ...       ...        ...
# 165887         No         No        Yes        No         No
# 165888         No         No         No        No         No
# 165889         No         No         No        No         No
# 165890         No         No        Yes        No         No
# 165891         No        NaN        NaN       NaN        NaN
#
# [165892 rows x 19 columns]

# %%
tree_census_subset.isna().sum()
# Out:
# tree_id          0
# tree_dbh         0
# stump_diam       0
# curb_loc         0
# status           0
# health        8467
# spc_latin     8466
# steward       8466
# sidewalk      8466
# problems      8480
# root_stone       0
# root_grate       0
# root_other       0
# trunk_wire       0
# trnk_light       0
# trnk_other       1
# brch_light       1
# brch_shoe        1
# brch_other       1
# dtype: int64

# %%
tree_census_subset[tree_census_subset['health'].isna()]
# Out:
#         tree_id  tree_dbh  stump_diam        curb_loc status health spc_latin  \
# 37       211205         0          16          OnCurb  Stump    NaN       NaN
# 57       187807         0           0          OnCurb   Dead    NaN       NaN
# 196      208322        10           0          OnCurb   Dead    NaN       NaN
# 209      209058         6           0          OnCurb   Dead    NaN       NaN
# 239      203597         0          15          OnCurb  Stump    NaN       NaN
# ...         ...       ...         ...             ...    ...    ...       ...
# 165838   380993        14           0  OffsetFromCurb   Dead    NaN       NaN
# 165840   351009         0           4          OnCurb  Stump    NaN       NaN
# 165841   355872         2           0          OnCurb   Dead    NaN       NaN
# 165873   373856         0          28          OnCurb  Stump    NaN       NaN
# 165885   361822         0           3          OnCurb  Stump    NaN       NaN
#
#        steward sidewalk problems root_stone root_grate root_other trunk_wire  \
# 37         NaN      NaN      NaN         No         No         No         No
# 57         NaN      NaN      NaN         No         No         No         No
# 196        NaN      NaN      NaN         No         No         No         No
# 209        NaN      NaN      NaN         No         No         No         No
# 239        NaN      NaN      NaN         No         No         No         No
# ...        ...      ...      ...        ...        ...        ...        ...
# 165838     NaN      NaN      NaN         No         No         No         No
# 165840     NaN      NaN      NaN         No         No         No         No
# 165841     NaN      NaN      NaN         No         No         No         No
# 165873     NaN      NaN      NaN         No         No         No         No
# 165885     NaN      NaN      NaN         No         No         No         No
#
#        trnk_light trnk_other brch_light brch_shoe brch_other
# 37             No         No         No        No         No
# 57             No         No         No        No         No
# 196            No         No         No        No         No
# 209            No         No         No        No         No
# 239            No         No         No        No         No
# ...           ...        ...        ...       ...        ...
# 165838         No         No         No        No         No
# 165840         No         No         No        No         No
# 165841         No         No         No        No         No
# 165873         No         No         No        No         No
# 165885         No         No         No        No         No
#
# [8467 rows x 19 columns]

# %%
tree_census_subset.describe()
# Out:
#              tree_id       tree_dbh    stump_diam
# count  165892.000000  165892.000000  165892.00000
# mean   268042.581143      11.263973       0.47936
# std     59111.647061       8.581197       3.46672
# min         7.000000       0.000000       0.00000
# 25%    224980.750000       5.000000       0.00000
# 50%    269674.500000       9.000000       0.00000
# 75%    315087.250000      16.000000       0.00000
# max    443757.000000     425.000000     140.00000

# %%
tree_census_subset.dtypes
# Out:
# tree_id        int64
# tree_dbh       int64
# stump_diam     int64
# curb_loc      object
# status        object
# health        object
# spc_latin     object
# steward       object
# sidewalk      object
# problems      object
# root_stone    object
# root_grate    object
# root_other    object
# trunk_wire    object
# trnk_light    object
# trnk_other    object
# brch_light    object
# brch_shoe     object
# brch_other    object
# dtype: object

# %%
tree_census_subset.hist(bins=60, figsize=(20,10))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fd728554f90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fd72862b3d0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7fd7284cbd90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fd72848e2d0>]],
#       dtype=object)

# %%
big_trees = tree_census_subset[tree_census_subset["stump_diam"]>50]
big_trees
# Out:
#         tree_id  tree_dbh  stump_diam curb_loc status health spc_latin  \
# 6122     200925         0          52   OnCurb  Stump    NaN       NaN
# 6177     200924         0          55   OnCurb  Stump    NaN       NaN
# 6466     166008         0          72   OnCurb  Stump    NaN       NaN
# 7042     206818         0         100   OnCurb  Stump    NaN       NaN
# 9872     192215         0          53   OnCurb  Stump    NaN       NaN
# ...         ...       ...         ...      ...    ...    ...       ...
# 156812   368877         0          55   OnCurb  Stump    NaN       NaN
# 156895   346263         0          53   OnCurb  Stump    NaN       NaN
# 156923   345674         0          66   OnCurb  Stump    NaN       NaN
# 161956   374839         0          61   OnCurb  Stump    NaN       NaN
# 165777   373854         0          54   OnCurb  Stump    NaN       NaN
#
#        steward sidewalk problems root_stone root_grate root_other trunk_wire  \
# 6122       NaN      NaN      NaN         No         No         No         No
# 6177       NaN      NaN      NaN         No         No         No         No
# 6466       NaN      NaN      NaN         No         No         No         No
# 7042       NaN      NaN      NaN         No         No         No         No
# 9872       NaN      NaN      NaN         No         No         No         No
# ...        ...      ...      ...        ...        ...        ...        ...
# 156812     NaN      NaN      NaN         No         No         No         No
# 156895     NaN      NaN      NaN         No         No         No         No
# 156923     NaN      NaN      NaN         No         No         No         No
# 161956     NaN      NaN      NaN         No         No         No         No
# 165777     NaN      NaN      NaN         No         No         No         No
#
#        trnk_light trnk_other brch_light brch_shoe brch_other
# 6122           No         No         No        No         No
# 6177           No         No         No        No         No
# 6466           No         No         No        No         No
# 7042           No         No         No        No         No
# 9872           No         No         No        No         No
# ...           ...        ...        ...       ...        ...
# 156812         No         No         No        No         No
# 156895         No         No         No        No         No
# 156923         No         No         No        No         No
# 161956         No         No         No        No         No
# 165777         No         No         No        No         No
#
# [74 rows x 19 columns]

# %%
big_trees[['tree_id','stump_diam']].plot(kind='scatter',x='tree_id',y='stump_diam',figsize=(20,10))

# %%
pd.DataFrame(tree_census_subset['spc_latin'].value_counts()).plot(kind='bar',figsize=(20,10))

# %%
tree_census_subset['steward'].value_counts()
# Out:
# None       111255
# 1or2        38905
# 3or4         6686
# 4orMore       580
# Name: steward, dtype: int64

# %%
tree_census_subset['sidewalk'].value_counts()
# Out:
# NoDamage    110320
# Damage       47106
# Name: sidewalk, dtype: int64

# %%
tree_census_subset['status'].value_counts()
# Out:
# Alive    157426
# Stump      4791
# Dead       3675
# Name: status, dtype: int64

# %%
tree_census_subset['curb_loc'].value_counts()
# Out:
# OnCurb            160085
# OffsetFromCurb      5807
# Name: curb_loc, dtype: int64

# %%
stumps = tree_census_subset[tree_census_subset['status'] == 'Stump']
stumps
# Out:
#         tree_id  tree_dbh  stump_diam curb_loc status health spc_latin  \
# 37       211205         0          16   OnCurb  Stump    NaN       NaN
# 239      203597         0          15   OnCurb  Stump    NaN       NaN
# 641      179766         0          30   OnCurb  Stump    NaN       NaN
# 644      180619         0          10   OnCurb  Stump    NaN       NaN
# 646      208828         0          15   OnCurb  Stump    NaN       NaN
# ...         ...       ...         ...      ...    ...    ...       ...
# 165814   370729         0           3   OnCurb  Stump    NaN       NaN
# 165836   379672         0          29   OnCurb  Stump    NaN       NaN
# 165840   351009         0           4   OnCurb  Stump    NaN       NaN
# 165873   373856         0          28   OnCurb  Stump    NaN       NaN
# 165885   361822         0           3   OnCurb  Stump    NaN       NaN
#
#        steward sidewalk problems root_stone root_grate root_other trunk_wire  \
# 37         NaN      NaN      NaN         No         No         No         No
# 239        NaN      NaN      NaN         No         No         No         No
# 641        NaN      NaN      NaN         No         No         No         No
# 644        NaN      NaN      NaN         No         No         No         No
# 646        NaN      NaN      NaN         No         No         No         No
# ...        ...      ...      ...        ...        ...        ...        ...
# 165814     NaN      NaN      NaN         No         No         No         No
# 165836     NaN      NaN      NaN         No         No         No         No
# 165840     NaN      NaN      NaN         No         No         No         No
# 165873     NaN      NaN      NaN         No         No         No         No
# 165885     NaN      NaN      NaN         No         No         No         No
#
#        trnk_light trnk_other brch_light brch_shoe brch_other
# 37             No         No         No        No         No
# 239            No         No         No        No         No
# 641            No         No         No        No         No
# 644            No         No         No        No         No
# 646            No         No         No        No         No
# ...           ...        ...        ...       ...        ...
# 165814         No         No         No        No         No
# 165836         No         No         No        No         No
# 165840         No         No         No        No         No
# 165873         No         No         No        No         No
# 165885         No         No         No        No         No
#
# [4791 rows x 19 columns]

# %%
deads = tree_census_subset[tree_census_subset['status'] == 'Dead']
deads
# Out:
#         tree_id  tree_dbh  stump_diam        curb_loc status health spc_latin  \
# 57       187807         0           0          OnCurb   Dead    NaN       NaN
# 196      208322        10           0          OnCurb   Dead    NaN       NaN
# 209      209058         6           0          OnCurb   Dead    NaN       NaN
# 266      210544         6           0          OnCurb   Dead    NaN       NaN
# 285      188609         9           0          OnCurb   Dead    NaN       NaN
# ...         ...       ...         ...             ...    ...    ...       ...
# 165784   371426         7           0          OnCurb   Dead    NaN       NaN
# 165791   345068         3           0          OnCurb   Dead    NaN       NaN
# 165792   386533         2           0          OnCurb   Dead    NaN       NaN
# 165838   380993        14           0  OffsetFromCurb   Dead    NaN       NaN
# 165841   355872         2           0          OnCurb   Dead    NaN       NaN
#
#        steward sidewalk problems root_stone root_grate root_other trunk_wire  \
# 57         NaN      NaN      NaN         No         No         No         No
# 196        NaN      NaN      NaN         No         No         No         No
# 209        NaN      NaN      NaN         No         No         No         No
# 266        NaN      NaN      NaN         No         No         No         No
# 285        NaN      NaN      NaN         No         No         No         No
# ...        ...      ...      ...        ...        ...        ...        ...
# 165784     NaN      NaN      NaN         No         No         No         No
# 165791     NaN      NaN      NaN         No         No         No         No
# 165792     NaN      NaN      NaN         No         No         No         No
# 165838     NaN      NaN      NaN         No         No         No         No
# 165841     NaN      NaN      NaN         No         No         No         No
#
#        trnk_light trnk_other brch_light brch_shoe brch_other
# 57             No         No         No        No         No
# 196            No         No         No        No         No
# 209            No         No         No        No         No
# 266            No         No         No        No         No
# 285            No         No         No        No         No
# ...           ...        ...        ...       ...        ...
# 165784         No         No         No        No         No
# 165791         No         No         No        No         No
# 165792         No         No         No        No         No
# 165838         No         No         No        No         No
# 165841         No         No         No        No         No
#
# [3675 rows x 19 columns]

# %%
tree_problems = tree_census_subset[['root_stone',
       'root_grate', 'root_other', 'trunk_wire', 'trnk_light', 'trnk_other',
       'brch_light', 'brch_shoe', 'brch_other']]
tree_problems
# Out:
#        root_stone root_grate root_other trunk_wire trnk_light trnk_other  \
# 0              No         No         No         No         No         No
# 1             Yes         No         No         No         No         No
# 2              No         No         No         No         No         No
# 3             Yes         No         No         No         No         No
# 4             Yes         No         No         No         No         No
# ...           ...        ...        ...        ...        ...        ...
# 165887         No         No         No         No         No         No
# 165888         No         No         No         No         No         No
# 165889         No         No         No         No         No         No
# 165890        Yes         No         No         No         No         No
# 165891         No         No         No         No         No        NaN
#
#        brch_light brch_shoe brch_other
# 0              No        No         No
# 1              No        No         No
# 2              No        No         No
# 3              No        No         No
# 4              No        No         No
# ...           ...       ...        ...
# 165887        Yes        No         No
# 165888         No        No         No
# 165889         No        No         No
# 165890        Yes        No         No
# 165891        NaN       NaN        NaN
#
# [165892 rows x 9 columns]

# %%
tree_problems.apply(pd.Series.value_counts)
# Out:
#      root_stone  root_grate  root_other  trunk_wire  trnk_light  trnk_other  \
# No       128510      164560      156916      162461      165571      156916
# Yes       37382        1332        8976        3431         321        8975
#
#      brch_light  brch_shoe  brch_other
# No       148625     165783      157821
# Yes       17266        108        8070
